# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#https://www.kaggle.com/datasets/smid80/weatherww2/data

# %%
df = pd.read_csv("Summary of Weather.csv")
# Out:
# /var/folders/f6/62dnf7ks59x_8m45s6sg7cj40000gn/T/ipykernel_56283/2360501030.py:1: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Summary of Weather.csv")

# %%
df.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4      0.0         NaN  42  ... NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
df.columns
# Out:
# Index(['STA', 'Date', 'Precip', 'WindGustSpd', 'MaxTemp', 'MinTemp',
#        'MeanTemp', 'Snowfall', 'PoorWeather', 'YR', 'MO', 'DA', 'PRCP', 'DR',
#        'SPD', 'MAX', 'MIN', 'MEA', 'SNF', 'SND', 'FT', 'FB', 'FTI', 'ITH',
#        'PGT', 'TSHDSBRSGF', 'SD3', 'RHX', 'RHN', 'RVG', 'WTE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 31 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   STA          119040 non-null  int64
#  1   Date         119040 non-null  object
#  2   Precip       119040 non-null  object
#  3   WindGustSpd  532 non-null     float64
#  4   MaxTemp      119040 non-null  float64
#  5   MinTemp      119040 non-null  float64
#  6   MeanTemp     119040 non-null  float64
#  7   Snowfall     117877 non-null  object
#  8   PoorWeather  34237 non-null   object
#  9   YR           119040 non-null  int64
#  10  MO           119040 non-null  int64
#  11  DA           119040 non-null  int64
#  12  PRCP         117108 non-null  object
#  13  DR           533 non-null     float64
#  14  SPD          532 non-null     float64
#  15  MAX          118566 non-null  float64
#  16  MIN          118572 non-null  float64
#  17  MEA          118542 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# STA                 0
# Date                0
# Precip              0
# WindGustSpd    118508
# MaxTemp             0
# MinTemp             0
# MeanTemp            0
# Snowfall         1163
# PoorWeather     84803
# YR                  0
# MO                  0
# DA                  0
# PRCP             1932
# DR             118507
# SPD            118508
# MAX               474
# MIN               468
# MEA               498
# SNF              1163
# SND            113477
# FT             119040
# FB             119040
# FTI            119040
# ITH            119040
# PGT            118515
# TSHDSBRSGF      84803
# SD3            119040
# RHX            119040
# RHN            119040
# RVG            119040
# WTE            119040
# dtype: int64

# %%
df = df.dropna(axis=1, thresh=len(df)*0.9)

# %%
df
# Out:
#           STA        Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall  \
# 0       10001    1942-7-1  1.016  25.555556  22.222222  23.888889      0.0
# 1       10001    1942-7-2      0  28.888889  21.666667  25.555556      0.0
# 2       10001    1942-7-3   2.54  26.111111  22.222222  24.444444      0.0
# 3       10001    1942-7-4   2.54  26.666667  22.222222  24.444444      0.0
# 4       10001    1942-7-5      0  26.666667  21.666667  24.444444      0.0
# ...       ...         ...    ...        ...        ...        ...      ...
# 119035  82506  1945-12-27      0  28.333333  18.333333  23.333333      0.0
# 119036  82506  1945-12-28  9.906  29.444444  18.333333  23.888889      0.0
# 119037  82506  1945-12-29      0  28.333333  18.333333  23.333333      0.0
# 119038  82506  1945-12-30      0  28.333333  18.333333  23.333333      0.0
# 119039  82506  1945-12-31      0  29.444444  17.222222  23.333333      0.0
#
#         YR  MO  DA  PRCP   MAX   MIN   MEA  SNF
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  object
#  2   Precip    119040 non-null  object
#  3   MaxTemp   119040 non-null  float64
#  4   MinTemp   119040 non-null  float64
#  5   MeanTemp  119040 non-null  float64
#  6   Snowfall  117877 non-null  object
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
#  10  PRCP      117108 non-null  object
#  11  MAX       118566 non-null  float64
#  12  MIN       118572 non-null  float64
#  13  MEA       118542 non-null  float64
#  14  SNF       117877 non-null  object
# dtypes: float64(6), int64(4), object(5)
# memory usage: 13.6+ MB

# %%
df.isnull().sum()
# Out:
# STA            0
# Date           0
# Precip         0
# MaxTemp        0
# MinTemp        0
# MeanTemp       0
# Snowfall    1163
# YR             0
# MO             0
# DA             0
# PRCP        1932
# MAX          474
# MIN          468
# MEA          498
# SNF         1163
# dtype: int64

# %%
df.columns
# Out:
# Index(['STA', 'Date', 'Precip', 'MaxTemp', 'MinTemp', 'MeanTemp', 'Snowfall',
#        'YR', 'MO', 'DA', 'PRCP', 'MAX', 'MIN', 'MEA', 'SNF'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  object
#  2   Precip    119040 non-null  object
#  3   MaxTemp   119040 non-null  float64
#  4   MinTemp   119040 non-null  float64
#  5   MeanTemp  119040 non-null  float64
#  6   Snowfall  117877 non-null  object
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
#  10  PRCP      117108 non-null  object
#  11  MAX       118566 non-null  float64
#  12  MIN       118572 non-null  float64
#  13  MEA       118542 non-null  float64
#  14  SNF       117877 non-null  object
# dtypes: float64(6), int64(4), object(5)
# memory usage: 13.6+ MB

# %%
df["Snowfall"]= df["Snowfall"].fillna(df["Snowfall"].mode()[0])
df["PRCP"]= df["PRCP"].fillna(df["PRCP"].mode()[0])
df["SNF"]= df["SNF"].fillna(df["SNF"].mode()[0])

# %%
df["MAX"] = df["MAX"].fillna(df["MAX"].mean())
df["MIN"] = df["MIN"].fillna(df["MIN"].mean())
df["MEA"] = df["MEA"].fillna(df["MEA"].mean())

# %%
df.isnull().sum()
# Out:
# STA         0
# Date        0
# Precip      0
# MaxTemp     0
# MinTemp     0
# MeanTemp    0
# Snowfall    0
# YR          0
# MO          0
# DA          0
# PRCP        0
# MAX         0
# MIN         0
# MEA         0
# SNF         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  object
#  2   Precip    119040 non-null  object
#  3   MaxTemp   119040 non-null  float64
#  4   MinTemp   119040 non-null  float64
#  5   MeanTemp  119040 non-null  float64
#  6   Snowfall  119040 non-null  object
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
#  10  PRCP      119040 non-null  object
#  11  MAX       119040 non-null  float64
#  12  MIN       119040 non-null  float64
#  13  MEA       119040 non-null  float64
#  14  SNF       119040 non-null  object
# dtypes: float64(6), int64(4), object(5)
# memory usage: 13.6+ MB

# %%
df[["Precip", "Snowfall", "PRCP", "SNF"]] = df[["Precip", "Snowfall", "PRCP", "SNF"]].apply(pd.to_numeric, errors="coerce")

# %%
df.isnull().sum()
# Out:
# STA             0
# Date            0
# Precip      16753
# MaxTemp         0
# MinTemp         0
# MeanTemp        0
# Snowfall       44
# YR              0
# MO              0
# DA              0
# PRCP        16753
# MAX             0
# MIN             0
# MEA             0
# SNF            44
# dtype: int64

# %%
 df["Date"].unique()
# Out:
# array(['1942-7-1', '1942-7-2', '1942-7-3', ..., '1941-8-22', '1941-8-23',
#        '1941-8-24'], dtype=object)

# %%
 df["Precip"].unique()
# Out:
# array([1.01600e+00, 0.00000e+00, 2.54000e+00,         nan, 3.55600e+00,
#        5.08000e-01, 2.54000e-01, 1.77800e+00, 3.30200e+00, 7.62000e-01,
#        5.58800e+00, 5.08000e+00, 2.03200e+00, 2.56540e+01, 4.01320e+01,
#        1.90500e+01, 2.38760e+01, 4.06400e+00, 1.21920e+01, 2.79400e+00,
#        3.32740e+01, 1.93040e+01, 4.77520e+01, 6.35000e+00, 3.04800e+00,
#        8.38200e+00, 1.01600e+01, 2.71780e+01, 3.04800e+01, 4.52120e+01,
#        1.06680e+01, 1.54940e+01, 5.76580e+01, 5.81660e+01, 1.14300e+01,
#        3.12420e+01, 1.77800e+01, 2.69240e+01, 2.66700e+01, 6.60400e+00,
#        5.33400e+00, 4.82600e+00, 7.62000e+00, 8.63600e+00, 7.87400e+00,
#        1.24460e+01, 9.09320e+01, 1.34620e+01, 1.19380e+01, 5.84200e+00,
#        4.31800e+00, 6.09600e+00, 9.14400e+00, 4.57200e+00, 9.90600e+00,
#        9.65200e+00, 1.52400e+00, 1.39700e+01, 1.72720e+01, 3.35280e+01,
#        1.27000e+00, 1.37160e+01, 8.12800e+00, 2.23520e+01, 3.91160e+01,
# ...

# %%
 df["Snowfall"].unique()
# Out:
# array([ 0.  , 22.86, 33.02, 30.48,  2.54,  5.08, 10.16,  7.62, 20.32,
#        15.24, 17.78, 12.7 , 25.4 , 27.94, 43.18, 38.1 , 45.72, 53.34,
#        58.42, 66.04, 76.2 , 81.28, 73.66, 63.5 , 50.8 , 48.26, 60.96,
#        55.88, 35.56, 78.74, 40.64, 86.36, 83.82, 68.58,   nan])

# %%
 df["PRCP"].unique()
# Out:
# array([4.000e-02, 0.000e+00, 1.000e-01,       nan, 1.400e-01, 2.000e-02,
#        1.000e-02, 7.000e-02, 1.300e-01, 3.000e-02, 2.200e-01, 2.000e-01,
#        8.000e-02, 1.010e+00, 1.580e+00, 7.500e-01, 9.400e-01, 1.600e-01,
#        4.800e-01, 1.100e-01, 1.310e+00, 7.600e-01, 1.880e+00, 2.500e-01,
#        1.200e-01, 3.300e-01, 4.000e-01, 1.070e+00, 1.200e+00, 1.780e+00,
#        4.200e-01, 6.100e-01, 2.270e+00, 2.290e+00, 4.500e-01, 1.230e+00,
#        7.000e-01, 1.060e+00, 1.050e+00, 2.600e-01, 2.100e-01, 1.900e-01,
#        3.000e-01, 3.400e-01, 3.100e-01, 4.900e-01, 3.580e+00, 5.300e-01,
#        4.700e-01, 2.300e-01, 1.700e-01, 2.400e-01, 3.600e-01, 1.800e-01,
#        3.900e-01, 3.800e-01, 6.000e-02, 5.500e-01, 6.800e-01, 1.320e+00,
#        5.000e-02, 5.400e-01, 3.200e-01, 8.800e-01, 1.540e+00, 1.420e+00,
#        3.860e+00, 1.500e-01, 5.900e-01, 3.080e+00, 5.760e+00, 5.800e-01,
#        8.600e-01, 4.760e+00, 1.660e+00, 9.200e-01, 8.300e-01, 1.770e+00,
# ...

# %%
df["SNF"].unique()
# Out:
# array([0. , 0.9, 1.3, 1.2, 0.1, 0.2, 0.4, 0.3, 0.8, 0.6, 0.7, 0.5, 1. ,
#        1.1, 1.7, 1.5, 1.8, 2.1, 2.3, 2.6, 3. , 3.2, 2.9, 2.5, 2. , 1.9,
#        2.4, 2.2, 1.4, 3.1, 1.6, 3.4, 3.3, 2.7, nan])

# %%
def clean_numeric(series):
    s=series.astype(str).str.strip()
    s=s.replace({"T":"0","M":np.nan})
    s=s.str.replace("<","",regex=False)
    s=s.str.replace(",","",regex=False)
    return pd.to_numeric(s, errors="coerce")

# %%
df["Precip"] = clean_numeric(df["Precip"])
df["Snowfall"] = clean_numeric(df["Snowfall"])
df["PRCP"] = clean_numeric(df["PRCP"])
df["SNF"] = clean_numeric(df["SNF"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119040 entries, 0 to 119039
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   STA       119040 non-null  int64
#  1   Date      119040 non-null  object
#  2   Precip    102287 non-null  float64
#  3   MaxTemp   119040 non-null  float64
#  4   MinTemp   119040 non-null  float64
#  5   MeanTemp  119040 non-null  float64
#  6   Snowfall  118996 non-null  float64
#  7   YR        119040 non-null  int64
#  8   MO        119040 non-null  int64
#  9   DA        119040 non-null  int64
#  10  PRCP      102287 non-null  float64
#  11  MAX       119040 non-null  float64
#  12  MIN       119040 non-null  float64
#  13  MEA       119040 non-null  float64
#  14  SNF       118996 non-null  float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 13.6+ MB

# %%
X=df[["MaxTemp","MinTemp","Precip","Snowfall","YR","MO","DA"]]
y=df["MeanTemp"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test=train_test_split(X, y, test_size=0.25, random_state=15)

# %%
y_train
# Out:
# 9278     27.777778
# 18364    23.333333
# 46563     0.000000
# 7912     26.666667
# 64350    22.777778
#            ...
# 49015    -1.111111
# 68229    27.222222
# 8076     27.222222
# 52981    23.888889
# 7624     26.666667
# Name: MeanTemp, Length: 89280, dtype: float64

# %%
y_test
# Out:
# 54542     23.888889
# 57708     25.555556
# 14285     28.888889
# 46171      2.222222
# 59171     24.444444
#             ...
# 83356     23.888889
# 118662    24.444444
# 27209     27.222222
# 14344     27.777778
# 112330    25.555556
# Name: MeanTemp, Length: 29760, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
sns.pairplot(df[["MaxTemp", "MinTemp", "Precip", "Snowfall", "MeanTemp"]])
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
regression= LinearRegression()

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer()

# %%
X_train =imputer.fit_transform(X_train)
X_test=imputer.transform(X_test)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
y_pred=regression.predict(X_test)
print("R^2:", r2_score(y_test,y_pred))
print("MSE:", mean_squared_error(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
plt.scatter(y_test, y_pred)
plt.show()
# Out:
# R^2: 0.9943724113245128
# MSE: 0.3865267874403392
# MAE: 0.1684970055591165

# %%
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r') 
plt.xlabel("Real Value (y_test)")
plt.ylabel("Prediction (y_pred)")
plt.title("Real vs Prediction")
plt.show()

# %%
print("Intercept:", regression.intercept_)
print("Coefficients:", regression.coef_)

for name, coef in zip(X.columns, regression.coef_):
    print(name, ":", coef)
# Out:
# Intercept: 22.392267772277375
# Coefficients: [ 4.38432835e+00  4.16703771e+00  3.88776125e-03  6.67623320e-03
#   6.30646467e-04 -3.60110467e-03  8.32697170e-04]
# MaxTemp : 4.384328354130601
# MinTemp : 4.167037708470678
# Precip : 0.003887761246633689
# Snowfall : 0.006676233203819089
# YR : 0.0006306464670741252
# MO : -0.0036011046701542432
# DA : 0.000832697170387055

# %%
residuals = y_test - y_pred

plt.hist(residuals, bins=50)
plt.xlabel("Residual (Real - Prediction)")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %%
#new data

# %%
new_data=pd.DataFrame({
    "MaxTemp": [30.0],
    "MinTemp": [20.0],
    "Precip": [5.0],
    "Snowfall": [0.0],
    "YR": [2025],
    "MO": [8],
    "DA": [20]
})

# %%
new_data_scaled=scaler.transform(new_data)

# %%
prediction=regression.predict(new_data_scaled)
print("Predicted MeanTeamp: ", prediction[0])
# Out:
# Predicted MeanTeamp:  26.100757558485846
